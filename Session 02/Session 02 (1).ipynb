# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows',None)

babar = pd.read_csv('babar.csv')

# %%
babar
# Out:
#       Opposition  Runs  4s  6s      SR
# 0    Afghanistan    51   4   0  108.51
# 1      Australia    68   5   1  123.63
# 2     Bangladesh    66   7   1  150.00
# 3        England    85   8   3  173.46
# 4          India    68   6   2  130.76
# 5        Namibia    70   7   0  142.85
# 6    New Zealand    79   7   2  136.20
# 7       Scotland    66   5   3  140.42
# 8   South Africa   122  15   4  206.77
# 9      Sri Lanka    34   2   0  109.67
# 10   West Indies    97  13   1  167.24
# 11      World-XI    86  10   2  165.38
# 12      Zimbabwe    82   9   1  149.09

# %%
babar.describe()
# Out:
#              Runs         4s         6s          SR
# count   13.000000  13.000000  13.000000   13.000000
# mean    74.923077   7.538462   1.538462  146.460000
# std     21.449404   3.573406   1.265924   27.220865
# min     34.000000   2.000000   0.000000  108.510000
# 25%     66.000000   5.000000   1.000000  130.760000
# 50%     70.000000   7.000000   1.000000  142.850000
# 75%     85.000000   9.000000   2.000000  165.380000
# max    122.000000  15.000000   4.000000  206.770000

# %%
plt.bar(babar['Opposition'],babar['Runs'])
plt.xticks(rotation = 90)
plt.show()

# %%
plt.bar(babar['Opposition'],babar['6s'])
plt.xticks(rotation = 90)
plt.show()

# %%
plt.bar(babar['Opposition'],babar['4s'])
plt.xticks(rotation = 90)
plt.show()

# %%
plt.bar(babar['Opposition'],babar['SR'])
plt.xticks(rotation = 90)
plt.show()

# %%
correlation_matrix = babar.corr()
correlation_matrix
# Out:
#           Runs        4s        6s        SR
# Runs  1.000000  0.958434  0.679900  0.924386
# 4s    0.958434  1.000000  0.520058  0.914471
# 6s    0.679900  0.520058  1.000000  0.711365
# SR    0.924386  0.914471  0.711365  1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
x = babar['Opposition']
y = babar['Runs']
fig,ax = plt.subplots(figsize = (10,6))
ax.barh(x,y)
pos = ['right','left','bottom','top']
for i in pos:
    ax.spines[i].set_visible(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.grid(visible = True , color = 'grey', alpha = 0.2)
ax.invert_yaxis()
ax.set_title('Babar Azam Statistics')
plt.show()
